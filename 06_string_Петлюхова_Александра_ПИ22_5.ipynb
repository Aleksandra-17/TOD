# %% [markdown]
# # Работа со строковыми значениями

# %% [markdown]
# __Автор задач: Блохин Н.В. (NVBlokhin@fa.ru)__
#
# Материалы:
# * Макрушин С.В. Лекция "Работа со строковыми значениям"
# * https://pyformat.info/
# * https://docs.python.org/3/library/re.html
#     * https://docs.python.org/3/library/re.html#flags
#     * https://docs.python.org/3/library/re.html#functions
# * https://pythonru.com/primery/primery-primeneniya-regulyarnyh-vyrazheniy-v-python
# * https://kanoki.org/2019/11/12/how-to-use-regex-in-pandas/
# * https://realpython.com/nltk-nlp-python/

# %% [markdown]
# ## Задачи для совместного разбора

# %%
import re
import pandas as pd

# %% [markdown]
# 1. Вывести на экран данные из словаря `obj` построчно в виде `k = v`, задав формат таким образом, чтобы знак равенства оказался на одной и той же позиции во всех строках. Строковые литералы обернуть в кавычки.

# %%
obj = {
    "home_page": "https://github.com/pypa/sampleproject",
    "keywords": "sample setuptools development",
    "license": "MIT",
}
for k, v in obj.items():
    print("{:<10} = '{}'".format(k, v))
# Out:
# home_page  = 'https://github.com/pypa/sampleproject'
# keywords   = 'sample setuptools development'
# license    = 'MIT'

# %% [markdown]
# 2. Написать регулярное выражение,которое позволит найти номера групп студентов.

# %%
obj = pd.Series(["Евгения гр.ПМ19-1", "Илья пм 20-4", "Анна 20-3"])
obj
import re
for val in obj:
    print(re.findall(r'\d{2}-\d', val))
# Out:
# ['19-1']
# ['20-4']
# ['20-3']

# %% [markdown]
# 3. Разбейте текст формулировки задачи 2 на слова.

# %%
string = 'Разбейте текст формулировки задачи 2 на слова.'.split()
res = ''
for i in range(len(string)):
    if i == (len(string)//2):
        res += ' '
    else:
        res += string[i]
res
# Out:
# 'Разбейтетекстформулировки 2наслова.'

# %% [markdown]
# ## Лабораторная работа 6.1

# %% [markdown]
# ### Форматирование строк

# %% [markdown]
# 6\.1\.1\. Загрузите данные из файла `recipes_sample.csv` (__ЛР2__) в виде `pd.DataFrame` `recipes` При помощи форматирования строк выведите информацию об id рецепта и времени выполнения 5 случайных рецептов в виде таблицы следующего вида:
#
#
#     |      id      |  minutes  |
#     |--------------------------|
#     |    61178     |    65     |
#     |    202352    |    80     |
#     |    364322    |    150    |
#     |    26177     |    20     |
#     |    224785    |    35     |
#
# Обратите внимание, что ширина столбцов заранее неизвестна и должна рассчитываться динамически, в зависимости от тех данных, которые были выбраны.

# %%
recipes = pd.read_csv('/content/sample_data/recipes_sample.csv')
random_recipes = recipes[['id', 'minutes']].sample(n=5)
max_id_len = len(str(random_recipes['id'].max()))
max_mins_len = len(str(random_recipes['minutes'].max()))
table_format = '|{{:^{}}}   |{{:^{}}} |'.format(max_id_len, max_mins_len)
print(table_format.format("id", "minutes"))
print('|'+'-' * (max_id_len + max_mins_len + 5)+'|')
for row in random_recipes.itertuples(index=False):
     print(table_format.format(*row))
# Out:
# |  id     |minutes |
# |-------------|
# |264560   |15 |
# |416088   |70 |
# |457944   |40 |
# |371488   |75 |
# |75389    |40 |

# %% [markdown]
# ## Работа с регулярными выражениями

# %% [markdown]
# 6\.1\.3\. Напишите регулярное выражение, которое ищет следующий паттерн в строке: число (1 цифра или более), затем пробел, затем слова: hour или hours или minute или minutes. Произведите поиск по данному регулярному выражению в каждом шаге рецепта с id 25082. Выведите на экран все непустые результаты, найденные по данному шаблону.

# %%
recipes = pd.read_csv('/content/sample_data/recipes_sample.csv')
pattern = r'(\d)+\s(hour|hours|minute|minutes)'
recipe = recipes[recipes['id']>25082]['description'].dropna()

for i in recipe:
    result = re.findall(pattern, i)
    if len(result) != 0:
        print(*[list(i) for i in result])
# Out:
# ['4', 'hour']
# ['5', 'minute']
# ['2', 'minute'] ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute'] ['2', 'hour']
# ['0', 'minute']
# ['1', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'minute']
# ['3', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['1', 'minute']
# ['6', 'hour'] ['6', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute'] ['0', 'minute'] ['5', 'minute'] ['0', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['5', 'minute'] ['0', 'minute']
# ['2', 'hour'] ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['4', 'hour']
# ['8', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['1', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'hour'] ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute'] ['2', 'hour']
# ['4', 'hour'] ['1', 'hour'] ['5', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['8', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['2', 'hour'] ['2', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['4', 'hour']
# ['0', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['4', 'hour'] ['4', 'hour']
# ['2', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['4', 'hour'] ['0', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['3', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'minute']
# ['8', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['8', 'hour']
# ['2', 'hour']
# ['5', 'minute']
# ['2', 'hour'] ['2', 'hour']
# ['8', 'hour']
# ['1', 'hour'] ['0', 'minute']
# ['0', 'minute']
# ['6', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute'] ['1', 'hour']
# ['0', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['4', 'hour'] ['4', 'hour']
# ['4', 'hour']
# ['2', 'minute']
# ['0', 'minute']
# ['5', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute'] ['5', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['1', 'hour']
# ['3', 'hour']
# ['0', 'minute']
# ['5', 'hour'] ['0', 'minute']
# ['2', 'hour']
# ['6', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'minute'] ['2', 'minute']
# ['4', 'hour']
# ['1', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['3', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['5', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['5', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['7', 'minute']
# ['2', 'minute'] ['0', 'minute']
# ['4', 'hour']
# ['2', 'hour']
# ['5', 'hour']
# ['4', 'hour']
# ['1', 'hour']
# ['6', 'hour'] ['0', 'minute']
# ['4', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute'] ['4', 'hour']
# ['0', 'minute']
# ['7', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute'] ['1', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['2', 'minute']
# ['4', 'hour']
# ['2', 'hour']
# ['6', 'hour']
# ['0', 'minute'] ['8', 'minute']
# ['6', 'hour']
# ['1', 'hour'] ['1', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['0', 'minute'] ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute'] ['2', 'hour']
# ['0', 'minute']
# ['6', 'hour']
# ['3', 'hour']
# ['5', 'minute'] ['0', 'minute']
# ['6', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'hour']
# ['9', 'hour']
# ['5', 'hour']
# ['4', 'hour'] ['0', 'minute']
# ['0', 'minute'] ['5', 'minute'] ['5', 'minute'] ['5', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['8', 'hour']
# ['1', 'hour']
# ['5', 'minute'] ['5', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['0', 'minute'] ['0', 'minute'] ['2', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['5', 'minute']
# ['4', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['8', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['0', 'minute'] ['8', 'hour']
# ['8', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['3', 'hour']
# ['1', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['2', 'hour']
# ['3', 'hour']
# ['2', 'hour']
# ['6', 'hour']
# ['4', 'minute']
# ['2', 'minute']
# ['1', 'hour']
# ['1', 'minute']
# ['8', 'hour']
# ['2', 'minute']
# ['4', 'hour']
# ['8', 'minute'] ['4', 'hour'] ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute'] ['4', 'hour']
# ['5', 'minute'] ['0', 'minute']
# ['4', 'hour'] ['2', 'hour'] ['4', 'hour']
# ['0', 'minute']
# ['4', 'hour']
# ['8', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['4', 'minute']
# ['4', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['5', 'minute']
# ['5', 'hour'] ['5', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['5', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['4', 'hour']
# ['3', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['0', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['1', 'hour']
# ['8', 'hour']
# ['2', 'hour']
# ['0', 'hour']
# ['1', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['1', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['1', 'hour'] ['2', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['5', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['3', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['6', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['6', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['6', 'hour'] ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['3', 'hour']
# ['2', 'hour']
# ['6', 'hour']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['2', 'hour']
# ['1', 'hour']
# ['0', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['1', 'minute'] ['1', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['8', 'minute']
# ['8', 'hour']
# ['2', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['5', 'minute']
# ['2', 'hour'] ['4', 'hour']
# ['1', 'hour']
# ['4', 'hour']
# ['5', 'minute'] ['1', 'hour']
# ['0', 'minute']
# ['8', 'hour'] ['8', 'hour']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['3', 'hour'] ['0', 'minute'] ['0', 'minute']
# ['5', 'minute']
# ['1', 'hour']
# ['3', 'minute']
# ['3', 'minute']
# ['8', 'hour']
# ['4', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['8', 'hour']
# ['0', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['5', 'minute'] ['0', 'minute']
# ['5', 'minute']
# ['2', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['8', 'hour']
# ['4', 'hour'] ['2', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['1', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['5', 'minute'] ['0', 'minute'] ['0', 'minute']
# ['8', 'hour'] ['4', 'hour']
# ['2', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['8', 'hour'] ['2', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['4', 'hour']
# ['3', 'minute']
# ['2', 'hour'] ['0', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour'] ['6', 'hour']
# ['6', 'hour']
# ['5', 'minute'] ['2', 'hour']
# ['2', 'hour']
# ['8', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['8', 'minute']
# ['0', 'minute']
# ['3', 'hour']
# ['5', 'minute']
# ['5', 'hour']
# ['2', 'hour']
# ['8', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['8', 'hour']
# ['8', 'hour'] ['4', 'hour']
# ['8', 'minute'] ['6', 'minute']
# ['0', 'hour'] ['0', 'hour'] ['5', 'hour']
# ['8', 'minute']
# ['1', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['3', 'hour']
# ['5', 'minute'] ['5', 'minute']
# ['3', 'hour']
# ['3', 'minute']
# ['0', 'minute'] ['0', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['3', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour'] ['2', 'hour']
# ['3', 'hour']
# ['5', 'hour']
# ['3', 'hour'] ['0', 'minute']
# ['2', 'hour']
# ['3', 'minute'] ['2', 'minute'] ['8', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['8', 'hour']
# ['0', 'minute']
# ['3', 'hour']
# ['5', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['1', 'hour'] ['5', 'minute']
# ['2', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'hour'] ['0', 'minute']
# ['8', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['5', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute'] ['2', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['6', 'hour']
# ['0', 'minute']
# ['1', 'hour'] ['1', 'hour']
# ['0', 'minute'] ['8', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['4', 'hour'] ['4', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['2', 'minute']
# ['4', 'hour']
# ['2', 'hour'] ['4', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['3', 'minute'] ['5', 'minute']
# ['0', 'minute']
# ['6', 'hour'] ['1', 'hour']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['6', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['3', 'hour'] ['4', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['9', 'minute']
# ['4', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['3', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['3', 'minute']
# ['5', 'minute'] ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['8', 'hour']
# ['0', 'minute'] ['0', 'minute']
# ['1', 'hour'] ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['3', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['8', 'hour']
# ['1', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['7', 'minute'] ['2', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour']
# ['4', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['8', 'minute']
# ['0', 'minute']
# ['0', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['2', 'minute']
# ['7', 'hour']
# ['0', 'minute']
# ['1', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['2', 'hour'] ['4', 'hour']
# ['2', 'hour']
# ['2', 'hour']
# ['5', 'minute']
# ['3', 'hour'] ['3', 'hour']
# ['0', 'hour']
# ['6', 'hour']
# ['5', 'minute']
# ['6', 'hour']
# ['5', 'minute']
# ['6', 'hour']
# ['2', 'hour']
# ['6', 'hour']
# ['5', 'minute']
# ['2', 'hour'] ['0', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['8', 'hour'] ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute'] ['2', 'minute']
# ['3', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['1', 'hour']
# ['0', 'minute'] ['8', 'hour']
# ['2', 'hour']
# ['8', 'hour']
# ['0', 'minute'] ['5', 'minute']
# ['4', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['8', 'hour']
# ['5', 'minute']
# ['1', 'hour'] ['3', 'hour']
# ['3', 'hour']
# ['4', 'hour']
# ['5', 'hour']
# ['0', 'minute']
# ['4', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['3', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['5', 'minute'] ['5', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'minute']
# ['2', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['7', 'hour']
# ['5', 'minute'] ['1', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute'] ['0', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['8', 'hour'] ['4', 'hour']
# ['1', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['2', 'hour'] ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['8', 'minute']
# ['2', 'hour']
# ['0', 'minute'] ['0', 'minute'] ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['6', 'hour']
# ['0', 'minute']
# ['8', 'minute']
# ['2', 'minute'] ['0', 'minute']
# ['1', 'hour'] ['2', 'hour']
# ['0', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['3', 'hour']
# ['5', 'minute'] ['1', 'hour'] ['0', 'minute']
# ['5', 'minute']
# ['2', 'hour'] ['2', 'hour']
# ['8', 'hour']
# ['0', 'minute']
# ['3', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute'] ['8', 'hour']
# ['5', 'minute']
# ['2', 'minute']
# ['2', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['1', 'hour']
# ['4', 'hour'] ['4', 'hour'] ['4', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['6', 'hour']
# ['1', 'hour']
# ['2', 'hour'] ['0', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute'] ['3', 'hour']
# ['2', 'hour'] ['2', 'hour']
# ['4', 'minute']
# ['5', 'minute']
# ['0', 'minute'] ['2', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['4', 'hour']
# ['5', 'minute']
# ['3', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['2', 'hour'] ['4', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['4', 'hour']
# ['4', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['2', 'hour']
# ['2', 'hour']
# ['4', 'hour']
# ['0', 'minute']
# ['8', 'hour']
# ['6', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['8', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['1', 'hour'] ['3', 'hour'] ['1', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['3', 'hour']
# ['2', 'hour']
# ['5', 'minute']
# ['8', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['4', 'hour']
# ['2', 'minute']
# ['4', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['1', 'hour']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute'] ['5', 'minute'] ['5', 'minute']
# ['5', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['6', 'hour']
# ['0', 'minute'] ['5', 'minute'] ['3', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['4', 'hour']
# ['3', 'minute']
# ['4', 'hour']
# ['2', 'hour']
# ['0', 'minute']
# ['6', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['5', 'minute']
# ['3', 'hour']
# ['0', 'minute']
# ['0', 'minute']
# ['0', 'minute']
# ['9', 'hour'] ['1', 'hour']
# ['4', 'hour']
# ['1', 'hour']
# ['0', 'minute']
# ['5', 'minute']
# ['5', 'minute'] ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['5', 'minute']
# ['0', 'minute']

# %% [markdown]
# 6\.1\.4\. Напишите регулярное выражение, которое ищет шаблон вида "this..., but" _в начале строки_ . Между словом "this" и частью ", but" может находиться произвольное число букв, цифр, знаков подчеркивания и пробелов. Никаких других символов вместо многоточия быть не может. Пробел между запятой и словом "but" может присутствовать или отсутствовать.
#
# Используя строковые методы `pd.Series`, выясните, для каких рецептов данный шаблон содержится в тексте описания. Выведите на экран количество таких рецептов и 3 примера подходящих описаний (текст описания должен быть виден на экране полностью).

# %%
from random import sample
p1 = re.compile(r'^\bthis\b[\s\d\w]+,\s?\bbut\b', re.M)
rec = []
for item in recipes.description.dropna():
    if p1.findall(item) != []:
        rec.append(item)
print(f'Количество подходящих описаний - {len(rec)}')
sample(rec,3)
# Out:
# Количество подходящих описаний - 142
# ['this entrée packs a powerful flavor punch, but goes easy on the fat and calories.  serve it with rice and a green salad for a spiced-up weeknight dinner!  recipe is from light & tasty’s feb/march 2006 issue.  i haven’t tried it yet, but man, it sure looks good.',
#  'this recipe is very simple, but if you do not know how to make candy then please follow instructions precisely. i have altered the instructions after a few reviews that it was crumbly. this is not the recipes fault, it is inexperience. proper candy making is about temperatures. 4 minutes of boiling (from the time the first small bubbles form) bring this candy up to proper fudge/softball temperature as long as you are cooking over medium heat. when in doubt, use a thermometer.',
#  'this is such an easy, but tasty, heat-and-eat appetizer. for some reason, the guys seem to really go for these. great for football season!']

# %% [markdown]
# ## Лабораторная 6.2

# %% [markdown]
# 6\.2\.1\. В текстах шагов рецептов обыкновенные дроби имеют вид "a / b". Используя регулярные выражения, уберите в тексте шагов рецепта с id 72367 пробелы до и после символа дроби. Выведите на экран шаги этого рецепта после их изменения.

# %%
recipes = pd.read_csv('/content/sample_data/recipes_sample.csv')

recipes = recipes.dropna(subset=['n_steps'])
myid = recipes[recipes['id'] == 72367].index[0]
recipes = recipes.loc[myid:]

recipes['description'] = recipes['description'].astype(str).apply(lambda x: re.sub(pattern, lambda y: y.group().replace(' ', ''), x))
recipes['description']
# Out:
# 2459     such a beautiful tart - just like from a europ...
# 2463     easy to make and delicious. it is very attract...
# 2464     i found this on a copy-cat site and its the be...
# 2465                                 this is a ww. recipe.
# 2466     this is a scallop recipe from ina garten's new...
#                                ...
# 29989           this has been a long time family favorite!
# 29992    this is a favourite winter warmer. by british ...
# 29994       this soup is a hearty meal!  from luisa musso.
# 29995    this is based on a french recipe but i changed...
# 29999    i've heard of the 'cookies by design' company,...
# Name: description, Length: 17269, dtype: object

# %% [markdown]
# ### Сегментация текста

# %%
import nltk
nltk.download(r'/content/sample_data/steps_sample.xml')
# Out:
# [nltk_data] Error loading /content/sample_data/steps_sample.xml:
# [nltk_data]     Package '/content/sample_data/steps_sample.xml' not
# [nltk_data]     found in index
# False

# %% [markdown]
# 6\.2\.2\. Разбейте тексты шагов рецептов на слова при помощи пакета `nltk`. Посчитайте и выведите на экран кол-во уникальных слов среди всех рецептов. Словом называется любая последовательность алфавитных символов (для проверки можно воспользоваться `str.isalpha`). При подсчете количества уникальных слов не учитывайте регистр.

# %% [markdown]
# 6\.2\.3\. Разбейте описания рецептов из `recipes` на предложения при помощи пакета `nltk`. Найдите 5 самых длинных описаний (по количеству _предложений_) рецептов в датасете и выведите строки фрейма, соответствующие этим рецептами, в порядке убывания длины.

# %% [markdown]
# 6\.2\.4\. Напишите функцию, которая для заданного предложения выводит информацию о частях речи слов, входящих в предложение, в следующем виде:
# ```
# PRP   VBD   DT      NNS     CC   VBD      NNS        RB
#  I  omitted the raspberries and added strawberries instead
# ```
# Для определения части речи слова можно воспользоваться `nltk.pos_tag`.
#
# Проверьте работоспособность функции на названии рецепта с id 241106.
#
# Обратите внимание, что часть речи должна находиться ровно посередине над соотвествующим словом, а между самими словами должен быть ровно один пробел.
